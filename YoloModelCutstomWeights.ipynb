# %% [markdown]
# <a href="https://colab.research.google.com/github/dita-hss/PPE-Detection/blob/main/YoloModelCutstomWeights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='http://ultralytics.com/images/bus.jpg'

# %%
# !yolo task=detect mode=train model=yolov8l.pt data = ../content/drive/MyDrive/Datasets/ConstructionPPE/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.108 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
